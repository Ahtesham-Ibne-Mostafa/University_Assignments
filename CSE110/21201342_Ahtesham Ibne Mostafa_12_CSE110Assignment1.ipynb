# %%
num1 = int( input ( ' Please Enter Your First Number: '))
num2 = int( input ( 'Please Enter Your second Number: '))
print ( 'sum =', num1 + num2 )
print ( 'product =', num1 * num2 )
print ( 'differance =', num1 - num2 )
# Out:
# sum = 9
# product = 20
# differance = -1

# %%
import math
radius = float ( input ( 'please enter the radius value :'))

print ( ' The area of the circle is :', math.pi * radius **2 )
print ( ' The area of the circle is :', math.pi * radius * 2 )
# Out:
#  The area of the circle is : 12.566370614359172
#  The area of the circle is : 12.566370614359172

# %%
x = int (input ( ' Please enter the first number :') )
y = int (input ( ' Please enter the Second number :') )

if (x > y):
    print ( 'First is greater')
elif (y>x):
    print ( 'Second is greater')
else :
    print ( 'The numbers are equal')

# %%
x = int (input ( ' Please enter the first number :') )
y = int (input ( ' Please enter the Second number :') )

if (x > y):
    print ( 'subtract :', x - y)
else :
    print ( 'subtract :', y - x)
# Out:
# subtract : 0

# %%
x = int (input ( ' Please enter a number :') )

if (x - 2*(x//2)==0):
    print ( 'The number is even')
else :
    print ( 'The number is odd')
# Out:
# The number is even

# %%
x = int (input ( ' Please enter a number :') )

if (x - 2*(x//2)==0 or x - 5*(x//5)==0 ):
    print ( x )
else :
    print ( 'not a multiple ')
# Out:
# 10

# %%
x = int (input ( ' Please enter a number :') )

if (x - 2*(x//2)==0 and x - 5*(x//5)==0 ):
    print ( 'multiple of 2 and 5 both' )
elif (x - 2*(x//2)==0 or x - 5*(x//5)==0 ):
    print (x)
else :
    print('not a multiple ')
# Out:
# not a multiple

# %%
x = int (input ( ' Please enter a number :') )

if (x - 2*(x//2)==0 and x - 5*(x//5)==0 ):
    print ( x )
else:
    print(' not multiple of 2 and 5 both' )
# Out:
#  not multiple of 2 and 5 both

# %%
x = int (input ( ' Please enter a number :') )

if (x - 2*(x//2) != 0 and x - 5*(x//5) != 0 ):
    print ( x )
else:
    print(' no' )
# Out:
#  no

# %%
x = int (input ( ' Please enter a number :') )

if (x - 2*(x//2) != 0 or x - 5*(x//5) != 0 ):
    print ( x )
else:
    print(' no' )
# Out:
# 14

# %%
x= int (input('Please enter your mark for a single subject in exam :'))
if ( 0<= x <=100 ):
    if (x >= 90):
        print ('A')
    elif ( 89 >= x >= 80):
        print ('B')
    elif ( 79 >= x >= 70):
        print ('C')
    elif ( 69 >= x >= 60):
        print('D')
    elif ( 59 >= x >= 50):
        print('E')
    else :
        print ('F')
else :
    print( 'Your mark is not Valid')
# Out:
# E

# %%
x= int (input('Please enter the hours you have worked :'))

if (x<0):
    print ('Hour can not be negative')
elif ( 0<= x <=40 ):
    print ( ' Your weekly salary is :', x * 200.00,'Tk')
elif ( 40 < x <= 168):
    print ( ' Your weekly salary is :', 8000.00+(x-40)*300.00,'Tk' )
else :
    print ( 'Impossible to work more than 168 hours weekly' )
# Out:
# Impossible to work more than 168 hours weekly

# %%
x= int (input('Please enter the number of seconds :'))
h=int (x/3600)
m=int((x-(h*3600))/60)
s=x-((h*3600)+m*60)
print ( ' Hours:',h,'Minutes:',m,'Seconds:',s )
# Out:
#  Hours: 1 Minutes: 1 Seconds: 59

# %%
x= int (input('Please enter the value of S :'))
if (x<100):
    print ( 'The value of L is :',3000-(125*x**2))
else :
    print ( 'The value of L is :',12000/(4+((x**2)/14900)))
# Out:
# The value of L is : 12.86516045474169

# %%
x= int (input('Please enter hour:'))
if ( 0<= x < 23 ):

    if ( 20 >= x >= 19):
        print ('Dinner')
    elif ( 17 >= x >= 16):
        print('Snacks')
    elif ( 13 >= x >= 12):
        print('Lunch')
    elif (6 >= x >=4):
        print ('Breakfast')
    else :
        print ('Patience is a virtue')
else :
    print( 'Wrong Time')
# Out:
# Breakfast

# %%
y = 0
while True:
    if y == 50:
        break
    y+=3
    print ( y + 2 )
# Out:
# 5
# 8
# 11
# 14
# 17
# 20
# 23
# 26
# 29
# 32
# 35
# 38
# 41
# 44
# 47
# 50
# 53
# 56
# 59
# 62
# 65
# 68
# 71
# 74
# 77
# 80
# 83
# 86
# 89
# 92
# 95
# 98
# 101
# 104
# 107
# 110
# 113
# 116
# 119
# 122
# 125
# 128
# 131
# 134
# 137
# 140
# 143
# 146
# 149
# 152
# 155
# 158
# 161
# 164
# 167
# 170
# 173
# 176
# 179
# 182
# 185
# 188
# 191
# 194
# 197
# 200
# 203
# 206
# 209
# 212
# 215
# 218
# 221
# 224
# 227
# 230
# 233
# 236
# 239
# 242
# 245
# 248
# 251
# 254
# 257
# 260
# 263
# 266
# 269
# 272
# 275
# 278
# 281
# 284
# 287
# 290
# 293
# 296
# 299
# 302
# 305
# 308
# 311
# 314
# 317
# 320
# 323
# 326
# 329
# 332
# 335
# 338
# 341
# 344
# 347
# 350
# 353
# 356
# 359
# 362
# 365
# 368
# 371
# 374
# 377
# 380
# 383
# 386
# 389
# 392
# 395
# 398
# 401
# 404
# 407
# 410
# 413
# 416
# 419
# 422
# 425
# 428
# 431
# 434
# 437
# 440
# 443
# 446
# 449
# 452
# 455
# 458
# 461
# 464
# 467
# 470
# 473
# 476
# 479
# 482
# 485
# 488
# 491
# 494
# 497
# 500
# 503
# 506
# 509
# 512
# 515
# 518
# ...

# %%
i = 1 
while True :
    print (i)
    if i % 5 == 0 :
        break
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i = 1 
while True :
    print (i)
    i += 1
    if i % 5 == 0 :
        break
# Out:
# 1
# 2
# 3
# 4
